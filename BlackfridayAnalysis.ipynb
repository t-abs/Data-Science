# %% [markdown]
# <a href="https://colab.research.google.com/github/t-abs/Data-Science/blob/main/BlackfridayAnalysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/BlackFriday.csv")

# %%
df.head(5)
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2             0.0                 3.0
# 1                          2             0.0                 1.0
# 2                          2             0.0                12.0
# 3                          2             0.0                12.0
# 4                         4+             0.0                 8.0
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 184662 entries, 0 to 184661
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     184662 non-null  int64
#  1   Product_ID                  184661 non-null  object
#  2   Gender                      184661 non-null  object
#  3   Age                         184661 non-null  object
#  4   Occupation                  184661 non-null  float64
#  5   City_Category               184661 non-null  object
#  6   Stay_In_Current_City_Years  184661 non-null  object
#  7   Marital_Status              184661 non-null  float64
#  8   Product_Category_1          184661 non-null  float64
#  9   Product_Category_2          127349 non-null  float64
#  10  Product_Category_3          56536 non-null   float64
#  11  Purchase                    184661 non-null  float64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 16.9+ MB

# %%
df.isnull()
# Out:
#         User_ID  Product_ID  Gender    Age  Occupation  City_Category  \
# 0         False       False   False  False       False          False
# 1         False       False   False  False       False          False
# 2         False       False   False  False       False          False
# 3         False       False   False  False       False          False
# 4         False       False   False  False       False          False
# ...         ...         ...     ...    ...         ...            ...
# 184657    False       False   False  False       False          False
# 184658    False       False   False  False       False          False
# 184659    False       False   False  False       False          False
# 184660    False       False   False  False       False          False
# 184661    False        True    True   True        True           True
#
#         Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                            False           False               False
# 1                            False           False               False
# 2                            False           False               False
# 3                            False           False               False
# 4                            False           False               False
# ...                            ...             ...                 ...
# 184657                       False           False               False
# 184658                       False           False               False
# 184659                       False           False               False
# 184660                       False           False               False
# 184661                        True            True                True
#
#         Product_Category_2  Product_Category_3  Purchase
# 0                     True                True     False
# 1                    False               False     False
# 2                     True                True     False
# 3                    False                True     False
# 4                     True                True     False
# ...                    ...                 ...       ...
# 184657               False               False     False
# 184658                True                True     False
# 184659               False                True     False
# 184660               False                True     False
# 184661                True                True      True
#
# [184662 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# User_ID                            0
# Product_ID                         1
# Gender                             1
# Age                                1
# Occupation                         1
# City_Category                      1
# Stay_In_Current_City_Years         1
# Marital_Status                     1
# Product_Category_1                 1
# Product_Category_2             57313
# Product_Category_3            128126
# Purchase                           1
# dtype: int64

# %%
df.dropna()
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 1       1000001  P00248942      F   0-17        10.0             A
# 6       1000004  P00184942      M  46-50         7.0             B
# 13      1000005  P00145042      M  26-35        20.0             A
# 14      1000006  P00231342      F  51-55         9.0             A
# 16      1000006   P0096642      F  51-55         9.0             A
# ...         ...        ...    ...    ...         ...           ...
# 184649  1004472  P00136742      F  46-50        16.0             B
# 184653  1004472  P00345842      F  46-50        16.0             B
# 184654  1004472  P00295942      F  46-50        16.0             B
# 184655  1004472  P00016342      F  46-50        16.0             B
# 184657  1004472  P00170942      F  46-50        16.0             B
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 1                               2             0.0                 1.0
# 6                               2             1.0                 1.0
# 13                              1             1.0                 1.0
# 14                              1             0.0                 5.0
# 16                              1             0.0                 2.0
# ...                           ...             ...                 ...
# 184649                          0             1.0                 1.0
# 184653                          0             1.0                 2.0
# 184654                          0             1.0                 2.0
# 184655                          0             1.0                 1.0
# 184657                          0             1.0                 5.0
#
#         Product_Category_2  Product_Category_3  Purchase
# 1                      6.0                14.0   15200.0
# 6                      8.0                17.0   19215.0
# 13                     2.0                 5.0   15665.0
# 14                     8.0                14.0    5378.0
# 16                     3.0                 4.0   13055.0
# ...                    ...                 ...       ...
# 184649                14.0                16.0   19607.0
# 184653                 8.0                14.0   13309.0
# 184654                 5.0                15.0    6600.0
# 184655                 2.0                 8.0   15763.0
# 184657                 8.0                14.0    6920.0
#
# [56536 rows x 12 columns]

# %%
del df['Product_Category_2']
del df['Product_Category_3']

# %%
df.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17        10.0             A
# 1  1000001  P00248942      F  0-17        10.0             A
# 2  1000001  P00087842      F  0-17        10.0             A
# 3  1000001  P00085442      F  0-17        10.0             A
# 4  1000002  P00285442      M   55+        16.0             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  Purchase
# 0                          2             0.0                 3.0    8370.0
# 1                          2             0.0                 1.0   15200.0
# 2                          2             0.0                12.0    1422.0
# 3                          2             0.0                12.0    1057.0
# 4                         4+             0.0                 8.0    7969.0

# %%
df['User_ID']
# Out:
# 0         1000001
# 1         1000001
# 2         1000001
# 3         1000001
# 4         1000002
#            ...
# 184657    1004472
# 184658    1004472
# 184659    1004472
# 184660    1004472
# 184661    1004472
# Name: User_ID, Length: 184662, dtype: int64

# %%
df['User_ID'].nunique()
# Out:
# 5886

# %%
df['User_ID'].unique()
# Out:
# array([1000001, 1000002, 1000003, ..., 1001282, 1001674, 1004293])

# %%
df
# Out:
#         User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001  P00069042      F   0-17        10.0             A
# 1       1000001  P00248942      F   0-17        10.0             A
# 2       1000001  P00087842      F   0-17        10.0             A
# 3       1000001  P00085442      F   0-17        10.0             A
# 4       1000002  P00285442      M    55+        16.0             C
# ...         ...        ...    ...    ...         ...           ...
# 184657  1004472  P00170942      F  46-50        16.0             B
# 184658  1004472  P00165842      F  46-50        16.0             B
# 184659  1004472  P00000742      F  46-50        16.0             B
# 184660  1004472  P00002442      F  46-50        16.0             B
# 184661  1004472        NaN    NaN    NaN         NaN           NaN
#
#        Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                               2             0.0                 3.0
# 1                               2             0.0                 1.0
# 2                               2             0.0                12.0
# 3                               2             0.0                12.0
# 4                              4+             0.0                 8.0
# ...                           ...             ...                 ...
# 184657                          0             1.0                 5.0
# 184658                          0             1.0                14.0
# 184659                          0             1.0                 5.0
# 184660                          0             1.0                 8.0
# 184661                        NaN             NaN                 NaN
#
#         Purchase
# 0         8370.0
# 1        15200.0
# 2         1422.0
# 3         1057.0
# 4         7969.0
# ...          ...
# 184657    6920.0
# 184658   15122.0
# 184659    7058.0
# 184660    6095.0
# 184661       NaN
#
# [184662 rows x 10 columns]

# %% [markdown]
# *unique datasets*

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M', nan], dtype=object)

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25', nan],
#       dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([10, 16, 15,  7, 20,  9,  1, 12, 17,  0,  3,  4, 11,  8, 19,  2, 18,
#         5, 14, 13,  6])

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9])

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1])

# %%
df['Purchase'].sum()/len(df['Purchase'])
# Out:
# 9333.859852635065

# %%
df.columns
# Out:
# Index(['User_ID', 'Product_ID', 'Gender', 'Age', 'Occupation', 'City_Category',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Purchase'],
#       dtype='object')

# %% [markdown]
# Analyzing gender

# %%
len(df[df['Gender']=='M']),len(df[df['Gender']=='F'])
# Out:
# (139460, 45201)

# %%
df.groupby('Gender').size().plot(kind='pie',  autopct = "%.1f",title = 'Gender Ratio',figsize = (6,6))
# Out:
# <Axes: title={'center': 'Gender Ratio'}>

# %%
df.groupby('Gender').size()
# Out:
# Gender
# F     45201
# M    139460
# dtype: int64

# %%
df.groupby('Gender').size().plot(kind = 'bar',
                                 figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender').size().plot(kind = 'bar',
                                 figsize = (6,6))
# Out:
# <Axes: xlabel='Gender'>

# %%
df.groupby('Gender').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f")
# Out:
# <ipython-input-26-615b98900524>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Gender').sum()['Purchase'].plot(kind = 'pie', autopct = "%0.1f")
# <Axes: ylabel='Purchase'>

# %% [markdown]
# Analysing Age and marital status

# %%
df.groupby('Age').size()
# Out:
# Age
# 0-17      4984
# 18-25    33896
# 26-35    73615
# 36-45    36806
# 46-50    15101
# 51-55    13029
# 55+       7230
# dtype: int64

# %%
df.groupby('Age').size().plot(kind='bar',figsize=(12,6),title='Purchase Distribution by Age')
# Out:
# <Axes: title={'center': 'Purchase Distribution by Age'}, xlabel='Age'>

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25', nan],
#       dtype=object)

# %%
df['Age'].nunique()
# Out:
# 7

# %%
lst = []
for i in df['Age'].unique():
    lst.append([i, df[df['Age'] == i]['Product_ID'].nunique()])

data = pd.DataFrame(lst , columns = ['Age','Products'])

# %%
data.plot.bar(x = 'Age', figsize = (8,6))
# Out:
# <Axes: xlabel='Age'>

# %%
df.groupby('Marital_Status').size().plot(kind='pie',autopct='%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('Gender').size().plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <Axes: >

# %%
df.groupby('Age').mean()['Purchase'].plot(kind = 'pie', autopct = '%0.1f')
# Out:
# <ipython-input-39-3e9764638eac>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Age').mean()['Purchase'].plot(kind = 'pie', autopct = '%0.1f')
# <Axes: ylabel='Purchase'>

# %% [markdown]
# Multicolumn Analysis

# %%
sns.set(rc = {'figure.figsize' : (12,6)})
sns.countplot(x = "Gender", hue = 'Age', data = df)
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (12,6)})
sns.countplot(x='Marital_Status',hue='Age',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.set(rc={'figure.figsize': (12,6)})
sns.countplot(x='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Age', ylabel='count'>

# %%
sns.countplot(x='Marital_Status',hue='City_Category',data=df)
# Out:
# <Axes: xlabel='Marital_Status', ylabel='count'>

# %%
sns.countplot(x = df['Stay_In_Current_City_Years'])
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Gender',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x='Stay_In_Current_City_Years',hue='Marital_Status',data=df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'Stay_In_Current_City_Years', hue = 'City_Category', data = df)
# Out:
# <Axes: xlabel='Stay_In_Current_City_Years', ylabel='count'>

# %%
sns.countplot(x = 'City_Category', hue = 'Age',data = df)
# Out:
# <Axes: xlabel='City_Category', ylabel='count'>

# %%
df.groupby('Stay_In_Current_City_Years').size().plot(kind='pie')
# Out:
# <Axes: >

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
sns.countplot(x = 'Product_Category_1', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Product_Category_1', ylabel='count'>

# %%
df.groupby('Product_Category_1').size().plot(kind='bar')
# Out:
# <Axes: xlabel='Product_Category_1'>

# %%
df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind = 'bar')
# Out:
# <ipython-input-56-6007a36588e2>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Stay_In_Current_City_Years').mean()['Purchase'].plot(kind = 'bar')
# <Axes: xlabel='Stay_In_Current_City_Years'>

# %%
sns.countplot(x=df['Occupation'])
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
#sort values
df.groupby('Occupation').size().sort_values().plot(kind='bar')
# Out:
# <Axes: xlabel='Occupation'>

# %%
df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# Out:
# <ipython-input-59-cf6aca9377fe>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('Occupation').sum()['Purchase'].sort_values().plot(kind = 'bar')
# <Axes: xlabel='Occupation'>

# %%
sns.countplot(x = 'Occupation', hue = 'Marital_Status', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>

# %%
sns.countplot(x = 'Occupation', hue = 'Gender', data = df)
# Out:
# <Axes: xlabel='Occupation', ylabel='count'>
